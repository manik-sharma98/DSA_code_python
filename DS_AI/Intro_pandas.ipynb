# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('World_Happiness_Report.csv')
df.head()
df.tail(2)
# Out:
#                       Country  Happiness Rank  Happiness Score   Economy  \
# 151                   Burundi             154            2.905  0.091623
# 152  Central African Republic             155            2.693  0.000000
#
#        Family    Health   Freedom  Generosity  Corruption  Dystopia  \
# 151  0.629794  0.151611  0.059901    0.204435    0.084148  1.683024
# 152  0.000000  0.018773  0.270842    0.280876    0.056565  2.066005
#
#      Job Satisfaction  Region
# 151              54.3  Africa
# 152              70.4  Africa

# %%
print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=153, step=1)
# Index(['Country', 'Happiness Rank', 'Happiness Score', 'Economy', 'Family',
#        'Health', 'Freedom', 'Generosity', 'Corruption', 'Dystopia',
#        'Job Satisfaction', 'Region'],
#       dtype='object')

# %%
columns_to_rows = {i: "_".join(i.split(" ")).lower() for i in df.columns}

df = df.rename(columns=columns_to_rows)
df.head()
# Out:
#        country  happiness_rank  happiness_score   economy    family    health  \
# 0       Norway               1            7.537  1.616463  1.533524  0.796667
# 1      Denmark               2            7.522  1.482383  1.551122  0.792566
# 2      Iceland               3            7.504  1.480633  1.610574  0.833552
# 3  Switzerland               4            7.494  1.564980  1.516912  0.858131
# 4      Finland               5            7.469  1.443572  1.540247  0.809158
#
#     freedom  generosity  corruption  dystopia  job_satisfaction  \
# 0  0.635423    0.362012    0.315964  2.277027              94.6
# 1  0.626007    0.355280    0.400770  2.313707              93.5
# 2  0.627163    0.475540    0.153527  2.322715              94.5
# 3  0.620071    0.290549    0.367007  2.276716              93.7
# 4  0.617951    0.245483    0.382612  2.430182              91.2
#
#            region
# 0  Western Europe
# 1  Western Europe
# 2  Western Europe
# 3  Western Europe
# ...

# %%
print(df.dtypes)
print(df.info)
# Out:
# country              object
# happiness_rank        int64
# happiness_score     float64
# economy             float64
# family              float64
# health              float64
# freedom             float64
# generosity          float64
# corruption          float64
# dystopia            float64
# job_satisfaction    float64
# region               object
# dtype: object
# <bound method DataFrame.info of                       country  happiness_rank  happiness_score   economy  \
# 0                      Norway               1            7.537  1.616463
# 1                     Denmark               2            7.522  1.482383
# 2                     Iceland               3            7.504  1.480633
# 3                 Switzerland               4            7.494  1.564980
# 4                     Finland               5            7.469  1.443572
# ..                        ...             ...              ...       ...
# ...

# %%
x = df.country
print(f"x:\n{x}")

x = df[["country"]]
print(x)
df[2:5]
# Out:
# x:
# 0                        Norway
# 1                       Denmark
# 2                       Iceland
# 3                   Switzerland
# 4                       Finland
#                  ...
# 148                      Rwanda
# 149                       Syria
# 150                    Tanzania
# 151                     Burundi
# 152    Central African Republic
# Name: country, Length: 153, dtype: object
#                       country
# 0                      Norway
# 1                     Denmark
# 2                     Iceland
# 3                 Switzerland
# 4                     Finland
# ..                        ...
# 148                    Rwanda
# 149                     Syria
# 150                  Tanzania
# 151                   Burundi
# 152  Central African Republic
#
# [153 rows x 1 columns]
#        country  happiness_rank  happiness_score   economy    family    health  \
# 2      Iceland               3            7.504  1.480633  1.610574  0.833552
# ...

# %%
index,row = next(df.iterrows())
print(row)
# Out:
# country                     Norway
# happiness_rank                   1
# happiness_score              7.537
# economy                   1.616463
# family                    1.533524
# health                    0.796667
# freedom                   0.635423
# generosity                0.362012
# corruption                0.315964
# dystopia                  2.277027
# job_satisfaction              94.6
# region              Western Europe
# Name: 0, dtype: object

# %%
df[df["region"]=="Western Europe"]

df["region"]
# Out:
# 0      Western Europe
# 1      Western Europe
# 2      Western Europe
# 3      Western Europe
# 4      Western Europe
#             ...
# 148            Africa
# 149      Asia-Pacific
# 150            Africa
# 151            Africa
# 152            Africa
# Name: region, Length: 153, dtype: object

# %%
df.describe()
# Out:
#        happiness_rank  happiness_score     economy      family      health  \
# count      153.000000       153.000000  153.000000  153.000000  153.000000
# mean        78.169935         5.349281    0.982433    1.186630    0.550117
# std         45.008741         1.134997    0.421901    0.288441    0.237769
# min          1.000000         2.693000    0.000000    0.000000    0.000000
# 25%         40.000000         4.497000    0.659517    1.041990    0.364509
# 50%         78.000000         5.279000    1.064578    1.251826    0.606042
# 75%        117.000000         6.098000    1.315175    1.416404    0.719217
# max        155.000000         7.537000    1.870766    1.610574    0.949492
#
#           freedom  generosity  corruption    dystopia  job_satisfaction
# count  153.000000  153.000000  153.000000  153.000000        151.000000
# mean     0.408489    0.245324    0.123179    1.853072         75.209934
# std      0.150744    0.134395    0.102133    0.499490         12.962365
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.hist('job_satisfaction')
# Out:
# array([[<Axes: title={'center': 'job_satisfaction'}>]], dtype=object)

# %%
df['non_sense'] = df['family'].apply(lambda x:x/10)

def my_function(x):
    y = x*2
    return y

df['apply'] = df['job_satisfaction'].apply(my_function)
df.head()
# Out:
#        country  happiness_rank  happiness_score   economy    family    health  \
# 0       Norway               1            7.537  1.616463  1.533524  0.796667
# 1      Denmark               2            7.522  1.482383  1.551122  0.792566
# 2      Iceland               3            7.504  1.480633  1.610574  0.833552
# 3  Switzerland               4            7.494  1.564980  1.516912  0.858131
# 4      Finland               5            7.469  1.443572  1.540247  0.809158
#
#     freedom  generosity  corruption  dystopia  ...          region  \
# 0  0.635423    0.362012    0.315964  2.277027  ...  Western Europe
# 1  0.626007    0.355280    0.400770  2.313707  ...  Western Europe
# 2  0.627163    0.475540    0.153527  2.322715  ...  Western Europe
# 3  0.620071    0.290549    0.367007  2.276716  ...  Western Europe
# 4  0.617951    0.245483    0.382612  2.430182  ...  Western Europe
#
#    Western Europe   North America    Asia-Pacific   Latin America  \
# ...
